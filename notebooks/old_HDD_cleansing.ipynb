# %%
import pandas as pd
import numpy as np


    
pd.set_option('display.max_columns', None)  # Mostrar todas las columnas
pd.set_option('display.max_rows', None)  # Mostrar todas las filas
pd.set_option('display.max_colwidth', None) # Mostrar el contenido completo de las celdas

# %%
df5 = pd.read_csv("C:/Users/luiso/IRONHACK/w3-project_SQL/data/old_HDD.csv")

df5.head()
# Out:
#   first_name last_name                  title  release_year  category_id
# 0   PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1   PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2   PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3   PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4   PENELOPE   GUINESS          CHEAPER CLYDE          2006           14

# %%
dim_original = df5.shape
old_HDD = df5.copy()
old_HDD.shape, dim_original
# Out:
# ((1000, 5), (1000, 5))

# %%
old_HDD.info()

old_HDD.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    1000 non-null   object
#  1   last_name     1000 non-null   object
#  2   title         1000 non-null   object
#  3   release_year  1000 non-null   int64
#  4   category_id   1000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 39.2+ KB
# first_name      0
# last_name       0
# title           0
# release_year    0
# category_id     0
# dtype: int64

# %%
old_HDD.duplicated().sum()
# Out:
# 0

# %%
old_HDD
# Out:
#     first_name     last_name                        title  release_year  \
# 0     PENELOPE       GUINESS             ACADEMY DINOSAUR          2006
# 1     PENELOPE       GUINESS         ANACONDA CONFESSIONS          2006
# 2     PENELOPE       GUINESS                  ANGELS LIFE          2006
# 3     PENELOPE       GUINESS        BULWORTH COMMANDMENTS          2006
# 4     PENELOPE       GUINESS                CHEAPER CLYDE          2006
# 5     PENELOPE       GUINESS           COLOR PHILADELPHIA          2006
# 6     PENELOPE       GUINESS              ELEPHANT TROJAN          2006
# 7     PENELOPE       GUINESS          GLEAMING JAWBREAKER          2006
# 8     PENELOPE       GUINESS               HUMAN GRAFFITI          2006
# 9     PENELOPE       GUINESS               KING EVOLUTION          2006
# 10    PENELOPE       GUINESS                   LADY STAGE          2006
# 11    PENELOPE       GUINESS              LANGUAGE COWBOY          2006
# ...

# %%
# Crear una columna que se llame "old_hdd" y que tenga el valor del indice de la fila empezando por 1 hasta el final

old_HDD["old_hdd_id"] = old_HDD.index + 1

old_HDD
# Out:
#     first_name     last_name                        title  release_year  \
# 0     PENELOPE       GUINESS             ACADEMY DINOSAUR          2006
# 1     PENELOPE       GUINESS         ANACONDA CONFESSIONS          2006
# 2     PENELOPE       GUINESS                  ANGELS LIFE          2006
# 3     PENELOPE       GUINESS        BULWORTH COMMANDMENTS          2006
# 4     PENELOPE       GUINESS                CHEAPER CLYDE          2006
# 5     PENELOPE       GUINESS           COLOR PHILADELPHIA          2006
# 6     PENELOPE       GUINESS              ELEPHANT TROJAN          2006
# 7     PENELOPE       GUINESS          GLEAMING JAWBREAKER          2006
# 8     PENELOPE       GUINESS               HUMAN GRAFFITI          2006
# 9     PENELOPE       GUINESS               KING EVOLUTION          2006
# 10    PENELOPE       GUINESS                   LADY STAGE          2006
# 11    PENELOPE       GUINESS              LANGUAGE COWBOY          2006
# ...

# %%
# Hacer un merge de la columna actor_id de la tabla actor para que en la tabla old_hdd aparezca la columna actor_id

actor = pd.read_csv("C:/Users/luiso/IRONHACK/Blockbuster_Project_2/actor_clean.csv")

actor.head()

# %%
actor = pd.read_csv("C:/Users/luiso/IRONHACK/Blockbuster_Project_2/actor_clean.csv")
actor_clean = actor.copy()
old_HDD['actor_id'] = None
for index, row in old_HDD.iterrows():
    last_name = row['last_name']
    first_name = row['first_name']
    matching_actor = actor_clean[(actor_clean['last_name'] == last_name) & (actor_clean['first_name'] == first_name)]
    if not matching_actor.empty:
        actor_id = matching_actor['actor_id'].values[0]
        old_HDD.at[index, 'actor_id'] = actor_id
old_HDD
# Out:
#     first_name     last_name                        title  release_year  \
# 0     PENELOPE       GUINESS             ACADEMY DINOSAUR          2006
# 1     PENELOPE       GUINESS         ANACONDA CONFESSIONS          2006
# 2     PENELOPE       GUINESS                  ANGELS LIFE          2006
# 3     PENELOPE       GUINESS        BULWORTH COMMANDMENTS          2006
# 4     PENELOPE       GUINESS                CHEAPER CLYDE          2006
# 5     PENELOPE       GUINESS           COLOR PHILADELPHIA          2006
# 6     PENELOPE       GUINESS              ELEPHANT TROJAN          2006
# 7     PENELOPE       GUINESS          GLEAMING JAWBREAKER          2006
# 8     PENELOPE       GUINESS               HUMAN GRAFFITI          2006
# 9     PENELOPE       GUINESS               KING EVOLUTION          2006
# 10    PENELOPE       GUINESS                   LADY STAGE          2006
# 11    PENELOPE       GUINESS              LANGUAGE COWBOY          2006
# ...

# %%
# Mover la columna old_hdd_id a la primera posición

old_HDD_clean = old_HDD[["old_hdd_id", "first_name", "last_name", "title", "release_year", "category_id", "actor_id"]]

old_HDD_clean.head()
# Out:
#    old_hdd_id first_name last_name                  title  release_year  \
# 0           1   PENELOPE   GUINESS       ACADEMY DINOSAUR          2006
# 1           2   PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006
# 2           3   PENELOPE   GUINESS            ANGELS LIFE          2006
# 3           4   PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006
# 4           5   PENELOPE   GUINESS          CHEAPER CLYDE          2006
#
#    category_id actor_id
# 0            6        1
# 1            2        1
# 2           13        1
# 3           10        1
# 4           14        1

# %%
# Exportar la tabla old_hdd_clean a un csv

old_HDD_clean.to_csv("C:/Users/luiso/IRONHACK/Blockbuster_Project_2/old_HDD_clean.csv", index=False)
