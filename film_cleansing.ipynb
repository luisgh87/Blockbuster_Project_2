# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

    
pd.set_option('display.max_columns', None)  # Mostrar todas las columnas
pd.set_option('display.max_rows', None)  # Mostrar todas las filas
pd.set_option('display.max_colwidth', None) # Mostrar el contenido completo de las celdas

# %%
df2 = pd.read_csv("C:/Users/luiso/IRONHACK/w3-project_SQL/data/film.csv")

df2.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                                                                                              description  \
# 0                       A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies
# 1                   A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China
# 2                       A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory
# 3                           A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank
# 4  A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico
#
# ...

# %%
dim_original = df2.shape
film = df2.copy()
film.shape, dim_original
# Out:
# ((1000, 13), (1000, 13))

# %%
film.info()

film.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   film_id               1000 non-null   int64
#  1   title                 1000 non-null   object
#  2   description           1000 non-null   object
#  3   release_year          1000 non-null   int64
#  4   language_id           1000 non-null   int64
#  5   original_language_id  0 non-null      float64
#  6   rental_duration       1000 non-null   int64
#  7   rental_rate           1000 non-null   float64
#  8   length                1000 non-null   int64
#  9   replacement_cost      1000 non-null   float64
#  10  rating                1000 non-null   object
#  11  special_features      1000 non-null   object
#  12  last_update           1000 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 101.7+ KB
# film_id                    0
# ...

# %%
film.duplicated().sum()
# Out:
# 0

# %%
# Eliminar la columna "oriiginal_language_id" porque no aporta información

film.drop(columns = ["original_language_id"], inplace = True)

# %%
film.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                                                                                              description  \
# 0                       A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies
# 1                   A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China
# 2                       A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory
# 3                           A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank
# 4  A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico
#
# ...

# %%
# Vamos a crear 3 columnas nuevas con los valores de special_features

film["Behind_the_Scenes"] = film["special_features"].str.contains("Behind the Scenes")
film["Commentaries"] = film["special_features"].str.contains("Commentaries")
film["Deleted_Scenes"] = film["special_features"].str.contains("Deleted Scenes")

# Especificamos que las peliculas que no tienen ninguno de estos valores, se les asigna un False a las no la tienen y True a las que si tienen

film["Behind_the_Scenes"] = film["Behind_the_Scenes"].fillna(False)
film["Commentaries"] = film["Commentaries"].fillna(False)
film["Deleted_Scenes"] = film["Deleted_Scenes"].fillna(False)

# Ahora quiero sustituir los valores True y False por "Included" y "Not_included" respectivamente a traves de una función

def special_features(x):
    if x == True:
        return "Included"
    else:
        return "Not_included"

# Aplicamos la función a las 3 columnas nuevas

film["Behind_the_Scenes"] = film["Behind_the_Scenes"].apply(special_features)
film["Commentaries"] = film["Commentaries"].apply(special_features)
film["Deleted_Scenes"] = film["Deleted_Scenes"].apply(special_features)








film.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                                                                                              description  \
# 0                       A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies
# 1                   A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China
# 2                       A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory
# 3                           A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank
# 4  A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico
#
# ...

# %%
# Eliminamos la columna "special_features" porque ya no nos aporta información

film.drop(columns = ["special_features"], inplace = True)

# %%
film.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                                                                                              description  \
# 0                       A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies
# 1                   A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China
# 2                       A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory
# 3                           A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank
# 4  A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico
#
# ...

# %%
# Cambiar los nombres de las columnas a minúsculas

film.columns = film.columns.str.lower()

film.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                                                                                              description  \
# 0                       A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies
# 1                   A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China
# 2                       A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory
# 3                           A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank
# 4  A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico
#
# ...

# %%
# Mover la columna "last_update" al final del dataframe

film = film[["film_id", "title", "description", "release_year", "language_id", "rental_duration", "rental_rate", "length", "replacement_cost", "rating", "commentaries", "behind_the_scenes", "deleted_scenes", "last_update"]]

film.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                                                                                              description  \
# 0                       A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies
# 1                   A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China
# 2                       A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory
# 3                           A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank
# 4  A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico
#
# ...

# %%
# Comprobar los valores unicos de todas las columnas

film["title"].unique()
# Out:
# array(['ACADEMY DINOSAUR', 'ACE GOLDFINGER', 'ADAPTATION HOLES',
#        'AFFAIR PREJUDICE', 'AFRICAN EGG', 'AGENT TRUMAN',
#        'AIRPLANE SIERRA', 'AIRPORT POLLOCK', 'ALABAMA DEVIL',
#        'ALADDIN CALENDAR', 'ALAMO VIDEOTAPE', 'ALASKA PHANTOM',
#        'ALI FOREVER', 'ALICE FANTASIA', 'ALIEN CENTER', 'ALLEY EVOLUTION',
#        'ALONE TRIP', 'ALTER VICTORY', 'AMADEUS HOLY',
#        'AMELIE HELLFIGHTERS', 'AMERICAN CIRCUS', 'AMISTAD MIDSUMMER',
#        'ANACONDA CONFESSIONS', 'ANALYZE HOOSIERS', 'ANGELS LIFE',
#        'ANNIE IDENTITY', 'ANONYMOUS HUMAN', 'ANTHEM LUKE',
#        'ANTITRUST TOMATOES', 'ANYTHING SAVANNAH', 'APACHE DIVINE',
#        'APOCALYPSE FLAMINGOS', 'APOLLO TEEN', 'ARABIA DOGMA',
#        'ARACHNOPHOBIA ROLLERCOASTER', 'ARGONAUTS TOWN', 'ARIZONA BANG',
#        'ARK RIDGEMONT', 'ARMAGEDDON LOST', 'ARMY FLINTSTONES',
#        'ARSENIC INDEPENDENCE', 'ARTIST COLDBLOODED', 'ATLANTIS CAUSE',
# ...
